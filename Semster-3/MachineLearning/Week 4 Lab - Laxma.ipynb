# %% [markdown]
# # Introduction to Machine Learning and Toolkit Exercises

# %% [markdown]
# ## Introduction
#
# We will be using the iris data set for this tutorial. This is a well-known data set containing iris species and sepal and petal measurements. The data we will use are in a file called `Iris_Data.csv` found in the [data](../../data) directory.

# %%
from __future__ import print_function
from pandas import read_csv
import os
import pandas as pd
3

# %% [markdown]
# ## Question 1
#
# Load the data from the file using the techniques learned today. Examine it.
#
# Determine the following:
#
# * The number of data points (rows). (*Hint:* check out the dataframe `.shape` attribute.)
# * The column names. (*Hint:* check out the dataframe `.columns` attribute.)
# * The data types for each column. (*Hint:* check out the dataframe `.dtypes` attribute.)

# %%
#Download the dataset and store the dataset inside a folder named 'data'. 
#The folder 'data' should be created where your ipynb file stored in your computer.
#dataset = os.sep.join(['data'] + ['Iris_Data.csv'])  #we set up the path here
#now, just read the data using read_csv and print
##Write your code

# %%
##Write your code

from pandas import read_csv

file_path = r'C:\Users\User\Downloads\Iris_dataset.csv'  # Adjust the path to your CSV file
iris_data = read_csv(file_path)

# Determine the number of data points (rows)
num_data_points = iris_data.shape[0]

# Get the column names
column_names = iris_data.columns.tolist()

# Get the data types for each column
data_types = iris_data.dtypes

# Print the results
print(f"Number of data points (rows): {num_data_points}")
print("Column names:", column_names)
print("Data types for each column:")
print(data_types)
# Out:
# Number of data points (rows): 150
# Column names: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# Data types for each column:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %% [markdown]
# ## Question 2
#
# Examine the species names and note that they all begin with 'Iris-'. Remove this portion of the name so the species name is shorter.
#
# *Hint:* there are multiple ways to do this, but you could use either the [string processing methods](http://pandas.pydata.org/pandas-docs/stable/text.html) or the [apply method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html).

# %%
##Write your code

def remove_prefix(species_name):
    return species_name.replace('Iris-', '')


iris_data['species'] = iris_data['species'].apply(remove_prefix)

# Display the modified DataFrame
print(iris_data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %% [markdown]
# ## Question 3
#
# Determine the following:
# * The number of each species present. (*Hint:* check out the series `.value_counts` method.)
# * The mean, count, max, std, min, etc using describe function.

# %%
##Write your code

# Number of each species present
species_counts = iris_data['species'].value_counts()
print("Number of each species:")
print(species_counts)

# Summary statistics using describe
summary_stats = iris_data.describe()
print("\nSummary statistics:")
print(summary_stats)
# Out:
# Number of each species:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# Summary statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
##Write your code

# %% [markdown]
# ## Question 4
#
# Calculate the following **for each species** in a separate dataframe:
#
# * The mean of each measurement (sepal_length, sepal_width, petal_length, and petal_width).
# * The median of each of these measurements.
#
# *Hint:* you may want to use Pandas [`groupby` method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) to group by species before calculating the statistic.
#
# If you finish both of these, try calculating both statistics (mean and median) in a single table (i.e. with a single groupby call). See the section of the Pandas documentation on [applying multiple functions at once](http://pandas.pydata.org/pandas-docs/stable/groupby.html#applying-multiple-functions-at-once) for a hint.

# %%
##Write your code

# Calculate mean and median separately for each species
mean_by_species = iris_data.groupby('species').mean()
median_by_species = iris_data.groupby('species').median()

# Combine mean and median into a single table
summary_by_species = mean_by_species.merge(median_by_species, on='species', suffixes=('_mean', '_median'))
print(summary_by_species)
# Out:
#             sepal_length_mean  sepal_width_mean  petal_length_mean  \
# species
# setosa                  5.006             3.418              1.464
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal_width_mean  sepal_length_median  sepal_width_median  \
# species
# setosa                 0.244                  5.0                 3.4
# versicolor             1.326                  5.9                 2.8
# virginica              2.026                  6.5                 3.0
#
#             petal_length_median  petal_width_median
# species
# setosa                     1.50                 0.2
# versicolor                 4.35                 1.3
# virginica                  5.55                 2.0

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %%
##Write your code

# %% [markdown]
# ## Question 5
#
# Make a scatter plot of `sepal_length` vs `sepal_width` using Matplotlib. Label the axes and give the plot a title.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

##Write your code


# Scatter plot
plt.scatter(iris_data['sepal_length'], iris_data['sepal_width'])

# Label the axes and give the plot a title
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')

# Show the plot
plt.show()

# %% [markdown]
# ## Question 6
#
# Make a histogram of any one of the four features. Label axes and title it as appropriate.

# %%
##Write your code

import matplotlib.pyplot as plt

# Histogram
plt.hist(iris_data['sepal_length'], bins=20, color='skyblue', edgecolor='black')

# Label the axes and give the plot a title
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')

# Show the plot
plt.show()

# %% [markdown]
# ## Question 7
#
# Now create a single plot with histograms for each feature (`petal_width`, `petal_length`, `sepal_width`,`sepal_length`) overlayed.

# %%
import seaborn as sns
sns.set_context('notebook')
##Write your code here

import matplotlib.pyplot as plt
import warnings
# To ignore all warnings
warnings.filterwarnings("ignore")

# Create a single plot with histograms for each feature
plt.figure(figsize=(10, 6))
sns.histplot(data=iris_data, x='petal_width', bins=20, color='skyblue', label='Petal Width')
sns.histplot(data=iris_data, x='petal_length', bins=20, color='salmon', label='Petal Length')
sns.histplot(data=iris_data, x='sepal_width', bins=20, color='lightgreen', label='Sepal Width')
sns.histplot(data=iris_data, x='sepal_length', bins=20, color='lightcoral', label='Sepal Length')

# Add labels and a title
plt.xlabel('Measurement')
plt.ylabel('Frequency')
plt.title('Histograms of Iris Features')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Question 8
#
# Make a [pairplot](http://seaborn.pydata.org/generated/seaborn.pairplot.html) with Seaborn to examine the correlation between each of the measurements.
#
# *Hint:* this plot may look complicated, but it is actually only a single line of code. This is the power of Seaborn and dataframe-aware plotting! See the lecture notes for reference.

# %%
##Write your code
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
# To ignore all warnings
warnings.filterwarnings("ignore")


# Create a pairplot to examine correlations
sns.pairplot(data=iris_data, hue='species', markers=["o", "s", "D"])

# Add a title to the plot
plt.suptitle("Pairplot of Iris Measurements by Species")

# Show the plot
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
